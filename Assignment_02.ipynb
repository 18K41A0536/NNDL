# %% [markdown]
# <a href="https://colab.research.google.com/github/18K41A0536/NNDL/blob/main/Assignment_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import Symbol,Derivative,symbols
x=Symbol('x')
y=Symbol('y')
function=x**2+y**2+10
partialderiv=Derivative(function,y)
dfy=partialderiv.doit()
partialderiv=Derivative(function,x)
dfx=partialderiv.doit()
print(f'first order derivative of given function are df/dx={dfx},df/dy={dfy}')
#step 1 :intialize variables
x1=-1.0
y1=2.0 #variable x,y
itr=100 #epoches
learning_rate=0.1
for i in range(0,itr):
  #step 2 :sub x,y in df/dx,df/dy
  x=symbols('x')
  y=symbols('y')
  dfxv=dfx.subs(x,x1)
  dfxv=round(dfxv,2)
  dfyv=dfy.subs(y,y1)
  dfyv=round(dfyv,2)
  #step 3 find change in x,y
  dx=(-1.0)*learning_rate*dfxv
  dy=(-1.0)*learning_rate*dfyv
  #step 4:update variables
  x1=x1+dx
  x1=round(x1,2)
  y1=y1+dy
  y1=round(y1,2)
  #step 5:increment iter
  #step6:terminate loop if iteration is greater than epoches
  #step7 print variables
  print(x1,y1)
  print(f'minimum value obtained at x={x1},y={y1} for given function')
# Out:
# first order derivative of given function are df/dx=2*x,df/dy=2*y
# -0.80 1.60
# minimum value obtained at x=-0.80,y=1.60 for given function
# -0.64 1.28
# minimum value obtained at x=-0.64,y=1.28 for given function
# -0.51 1.02
# minimum value obtained at x=-0.51,y=1.02 for given function
# -0.41 0.82
# minimum value obtained at x=-0.41,y=0.82 for given function
# -0.33 0.66
# minimum value obtained at x=-0.33,y=0.66 for given function
# -0.26 0.53
# minimum value obtained at x=-0.26,y=0.53 for given function
# -0.21 0.42
# minimum value obtained at x=-0.21,y=0.42 for given function
# -0.17 0.34
# minimum value obtained at x=-0.17,y=0.34 for given function
# -0.14 0.27
# minimum value obtained at x=-0.14,y=0.27 for given function
# -0.11 0.22
# minimum value obtained at x=-0.11,y=0.22 for given function
# -0.09 0.18
# minimum value obtained at x=-0.09,y=0.18 for given function
# -0.07 0.14
# minimum value obtained at x=-0.07,y=0.14 for given function
# -0.06 0.11
# ...
